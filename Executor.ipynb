# %%
# import the pd to read data
import pandas as pd
# import the main function
import Capstone_group01_KunWeiFan_TianyuMa as cap

# %%
# input the dataset
df = pd.read_csv("Provisional_COVID-19_Deaths_by_Sex_and_Age.csv")

# %%
# call the data cleaning function of the main function
df_clean = cap.main_function_Group1_Clean(df)

# %%
# call the first part of the analysis function
cap.main_function_Group1_Part1(df_clean)
# Out:
# 'Success End Main Function'

# %%
# call the second part of the analysis function
cap.main_function_Group1_Part2(df_clean)
# Out:
# OLS Regression Model of COVID-19 Deaths by Age Group:
#                              OLS Regression Results
# ...
# Dep. Variable:        COVID-19 Deaths   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     425.8
# Date:                Sat, 13 May 2023   Prob (F-statistic):               0.00
# Time:                        02:21:31   Log-Likelihood:            -2.0314e+05
# No. Observations:               33920   AIC:                         4.063e+05
# Df Residuals:                   33912   BIC:                         4.064e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...
